# %%
from fer_api import FER2013
api = FER2013()
api.prepare_sess(tModel='/home/ubuntu/MyFiles/model/fer_cliquenet/fer_model_499-500')
api.sess_perform('/home/ubuntu/MyFiles/data/fer2013/valid/46_3.png')
# Out:
# 100
# 100100
#
# model path :/home/ubuntu/MyFiles/model/fer_cliquenet/fer_model_499-500
# 100
# 100
# 100
# 100100
#
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# INFO:tensorflow:Restoring parameters from /home/ubuntu/MyFiles/model/fer_cliquenet/fer_model_499-500
# 100
# 100100
#
# 100
# 100
# 100
# 100
# 100100
#
# 100
# 100
# 100
# 100100
#
# 100
# 100
# 100
# 100
# 100
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Key BatchNorm_1/gamma/ExponentialMovingAverage_4 not found in checkpoint
# 	 [[Node: save_6/RestoreV2_21 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_6/Const_0_0, save_6/RestoreV2_21/tensor_names, save_6/RestoreV2_21/shape_and_slices)]]
# 	 [[Node: save_6/RestoreV2_5461/_1265 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_14222_save_6/RestoreV2_5461", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-10-8161ad412fd8> in <module>
#       1 from fer_api import FER2013
#       2 api = FER2013()
# ----> 3 api.prepare_sess(tModel='/home/ubuntu/MyFiles/model/fer_cliquenet/fer_model_499-500')
#       4 api.sess_perform('/home/ubuntu/MyFiles/data/fer2013/valid/46_3.png')
#
# ~/MyFiles/repo/fer2013/fer_api.py in prepare_sess(self, tModel)
#      89         saver = tf.train.Saver(variables_to_restore)
#      90         self.sess = tf.Session()
# ---> 91         saver.restore(self.sess, tModel)
#      92
#      93     def sess_perform(self,datapath):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1684     if context.in_graph_mode():
#    1685       sess.run(self.saver_def.restore_op_name,
# -> 1686                {self.saver_def.filename_tensor_name: save_path})
#    1687     else:
#    1688       self._build_eager(save_path, build_save=False, build_restore=True)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1361         except KeyError:
#    1362           pass
# -> 1363       raise type(e)(node_def, op, message)
#    1364
#    1365   def _extend_graph(self):
#
# NotFoundError: Key BatchNorm_1/gamma/ExponentialMovingAverage_4 not found in checkpoint
# 	 [[Node: save_6/RestoreV2_21 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_6/Const_0_0, save_6/RestoreV2_21/tensor_names, save_6/RestoreV2_21/shape_and_slices)]]
# 	 [[Node: save_6/RestoreV2_5461/_1265 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_14222_save_6/RestoreV2_5461", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# Caused by op 'save_6/RestoreV2_21', defined at:
#   File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.5/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 345, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 1312, in _run_once
#     handle._run()
#   File "/usr/lib/python3.5/asyncio/events.py", line 125, in _run
#     self._callback(*self._args)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 346, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 259, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 513, in execute_request
#     user_expressions, allow_stdin,
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2817, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2843, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3018, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3183, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-8161ad412fd8>", line 3, in <module>
#     api.prepare_sess(tModel='/home/ubuntu/MyFiles/model/fer_cliquenet/fer_model_499-500')
#   File "/home/ubuntu/MyFiles/repo/fer2013/fer_api.py", line 89, in prepare_sess
#     saver = tf.train.Saver(variables_to_restore)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 1239, in __init__
#     self.build()
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 1248, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 1284, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 765, in _build_internal
#     restore_sequentially, reshape)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 428, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 268, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gen_io_ops.py", line 1031, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Key BatchNorm_1/gamma/ExponentialMovingAverage_4 not found in checkpoint
# 	 [[Node: save_6/RestoreV2_21 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_6/Const_0_0, save_6/RestoreV2_21/tensor_names, save_6/RestoreV2_21/shape_and_slices)]]
# 	 [[Node: save_6/RestoreV2_5461/_1265 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_14222_save_6/RestoreV2_5461", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
TFRPATH='/home/ubuntu/MyFiles/data/fer2013/temporary/test.tfrecords'
api.csv_to_tfrecord(csv_path=config.test_data_path,
                    tfr_path=TFRPATH)

# %%
import time
import threading
from fer_api import FER2013
api = FER2013()
tfRecord_train='/home/ubuntu/MyFiles/data/fer2013/fer2013_train.tfrecords'
api.incre_train(datapath=tfRecord_train,
               step_num=500,
               save_interval=100)
# Out:
# 2020-05-12 19:17:42 : After 5 training step(s), loss,accuracy on training batch is 2.46426 , 0.25.
# 2020-05-12 19:17:43 : After 10 training step(s), loss,accuracy on training batch is 2.39308 , 0.195312.
# 2020-05-12 19:17:44 : After 15 training step(s), loss,accuracy on training batch is 2.41132 , 0.210938.
# 2020-05-12 19:17:45 : After 20 training step(s), loss,accuracy on training batch is 2.3483 , 0.15625.
# 2020-05-12 19:17:45 : After 25 training step(s), loss,accuracy on training batch is 2.31584 , 0.179688.
# 2020-05-12 19:17:46 : After 30 training step(s), loss,accuracy on training batch is 2.30619 , 0.273438.
# 2020-05-12 19:17:59 : After 110 training step(s), loss,accuracy on training batch is 2.08544 , 0.351562.
# 2020-05-12 19:18:00 : After 115 training step(s), loss,accuracy on training batch is 2.1857 , 0.335938.
# 2020-05-12 19:18:01 : After 120 training step(s), loss,accuracy on training batch is 2.05623 , 0.375.
# 2020-05-12 19:18:02 : After 125 training step(s), loss,accuracy on training batch is 2.15135 , 0.320312.
# 2020-05-12 19:18:02 : After 130 training step(s), loss,accuracy on training batch is 2.11621 , 0.351562.
# 2020-05-12 19:18:03 : After 135 training step(s), loss,accuracy on training batch is 2.16614 , 0.34375.
# 2020-05-12 19:18:04 : After 140 training step(s), loss,accuracy on training batch is 1.98768 , 0.445312.
# 2020-05-12 19:18:05 : After 145 training step(s), loss,accuracy on training batch is 2.16366 , 0.3125.
# 2020-05-12 19:18:06 : After 150 training step(s), loss,accuracy on training batch is 2.13157 , 0.320312.
# 2020-05-12 19:18:07 : After 155 training step(s), loss,accuracy on training batch is 2.0237 , 0.296875.
# 2020-05-12 19:18:07 : After 160 training step(s), loss,accuracy on training batch is 2.09238 , 0.34375.
# 2020-05-12 19:18:08 : After 165 training step(s), loss,accuracy on training batch is 1.93115 , 0.398438.
# 2020-05-12 19:18:09 : After 170 training step(s), loss,accuracy on training batch is 2.07688 , 0.34375.
# 2020-05-12 19:18:10 : After 175 training step(s), loss,accuracy on training batch is 2.07986 , 0.429688.
# 2020-05-12 19:18:11 : After 180 training step(s), loss,accuracy on training batch is 2.03946 , 0.328125.
# 2020-05-12 19:18:12 : After 185 training step(s), loss,accuracy on training batch is 1.95178 , 0.421875.
# 2020-05-12 19:18:12 : After 190 training step(s), loss,accuracy on training batch is 2.02672 , 0.414062.
# 2020-05-12 19:18:13 : After 195 training step(s), loss,accuracy on training batch is 1.86866 , 0.445312.
# 2020-05-12 19:18:14 : After 200 training step(s), loss,accuracy on training batch is 2.01393 , 0.40625.
# 2020-05-12 19:18:15 : After 205 training step(s), loss,accuracy on training batch is 1.91634 , 0.421875.
# 2020-05-12 19:18:16 : After 210 training step(s), loss,accuracy on training batch is 1.95969 , 0.34375.
# 2020-05-12 19:18:16 : After 215 training step(s), loss,accuracy on training batch is 2.04673 , 0.34375.
# 2020-05-12 19:18:17 : After 220 training step(s), loss,accuracy on training batch is 1.99053 , 0.328125.
# 2020-05-12 19:18:18 : After 225 training step(s), loss,accuracy on training batch is 1.9844 , 0.398438.
# 2020-05-12 19:18:19 : After 230 training step(s), loss,accuracy on training batch is 1.98572 , 0.398438.
# 2020-05-12 19:18:20 : After 235 training step(s), loss,accuracy on training batch is 1.93116 , 0.382812.
# 2020-05-12 19:18:21 : After 240 training step(s), loss,accuracy on training batch is 1.97556 , 0.335938.
# 2020-05-12 19:18:21 : After 245 training step(s), loss,accuracy on training batch is 1.93887 , 0.421875.
# 2020-05-12 19:18:22 : After 250 training step(s), loss,accuracy on training batch is 2.06697 , 0.335938.
# 2020-05-12 19:18:23 : After 255 training step(s), loss,accuracy on training batch is 1.9847 , 0.382812.
# 2020-05-12 19:18:24 : After 260 training step(s), loss,accuracy on training batch is 2.10632 , 0.328125.
# 2020-05-12 19:18:25 : After 265 training step(s), loss,accuracy on training batch is 1.95441 , 0.398438.
# 2020-05-12 19:18:25 : After 270 training step(s), loss,accuracy on training batch is 1.90832 , 0.429688.
# 2020-05-12 19:18:26 : After 275 training step(s), loss,accuracy on training batch is 1.94343 , 0.390625.
# 2020-05-12 19:18:27 : After 280 training step(s), loss,accuracy on training batch is 1.83025 , 0.453125.
# 2020-05-12 19:18:28 : After 285 training step(s), loss,accuracy on training batch is 1.91349 , 0.445312.
# 2020-05-12 19:18:29 : After 290 training step(s), loss,accuracy on training batch is 1.93115 , 0.4375.
# 2020-05-12 19:18:30 : After 295 training step(s), loss,accuracy on training batch is 2.03182 , 0.367188.
# 2020-05-12 19:18:30 : After 300 training step(s), loss,accuracy on training batch is 1.82198 , 0.46875.
# 2020-05-12 19:18:31 : After 305 training step(s), loss,accuracy on training batch is 1.77544 , 0.460938.
# 2020-05-12 19:18:32 : After 310 training step(s), loss,accuracy on training batch is 1.83348 , 0.453125.
# 2020-05-12 19:18:33 : After 315 training step(s), loss,accuracy on training batch is 1.83055 , 0.429688.
# 2020-05-12 19:18:34 : After 320 training step(s), loss,accuracy on training batch is 1.86114 , 0.421875.
# 2020-05-12 19:18:34 : After 325 training step(s), loss,accuracy on training batch is 2.02567 , 0.367188.
# 2020-05-12 19:18:35 : After 330 training step(s), loss,accuracy on training batch is 1.7819 , 0.5.
# 2020-05-12 19:18:36 : After 335 training step(s), loss,accuracy on training batch is 1.85158 , 0.421875.
# 2020-05-12 19:18:37 : After 340 training step(s), loss,accuracy on training batch is 1.96993 , 0.4375.
# 2020-05-12 19:18:38 : After 345 training step(s), loss,accuracy on training batch is 1.83065 , 0.414062.
# 2020-05-12 19:18:38 : After 350 training step(s), loss,accuracy on training batch is 1.82223 , 0.421875.
# 2020-05-12 19:18:39 : After 355 training step(s), loss,accuracy on training batch is 1.92624 , 0.414062.
# 2020-05-12 19:18:40 : After 360 training step(s), loss,accuracy on training batch is 1.84245 , 0.46875.
# 2020-05-12 19:18:41 : After 365 training step(s), loss,accuracy on training batch is 1.84185 , 0.414062.
# 2020-05-12 19:18:42 : After 370 training step(s), loss,accuracy on training batch is 1.89447 , 0.445312.
# 2020-05-12 19:18:43 : After 375 training step(s), loss,accuracy on training batch is 1.82643 , 0.476562.
# 2020-05-12 19:18:43 : After 380 training step(s), loss,accuracy on training batch is 1.71324 , 0.445312.
# 2020-05-12 19:18:44 : After 385 training step(s), loss,accuracy on training batch is 1.80365 , 0.445312.
# 2020-05-12 19:18:45 : After 390 training step(s), loss,accuracy on training batch is 1.71042 , 0.421875.
# 2020-05-12 19:18:46 : After 395 training step(s), loss,accuracy on training batch is 1.85517 , 0.414062.
# 2020-05-12 19:18:47 : After 400 training step(s), loss,accuracy on training batch is 1.8558 , 0.445312.
# 2020-05-12 19:18:47 : After 405 training step(s), loss,accuracy on training batch is 1.88835 , 0.414062.
# 2020-05-12 19:18:48 : After 410 training step(s), loss,accuracy on training batch is 1.71502 , 0.515625.
# 2020-05-12 19:18:49 : After 415 training step(s), loss,accuracy on training batch is 1.73203 , 0.421875.
# 2020-05-12 19:18:50 : After 420 training step(s), loss,accuracy on training batch is 1.77251 , 0.484375.
# 2020-05-12 19:18:51 : After 425 training step(s), loss,accuracy on training batch is 1.76611 , 0.4375.
# 2020-05-12 19:18:51 : After 430 training step(s), loss,accuracy on training batch is 1.71316 , 0.5.
# 2020-05-12 19:18:52 : After 435 training step(s), loss,accuracy on training batch is 1.8457 , 0.414062.
# 2020-05-12 19:18:53 : After 440 training step(s), loss,accuracy on training batch is 1.7775 , 0.453125.
# 2020-05-12 19:18:54 : After 445 training step(s), loss,accuracy on training batch is 1.76676 , 0.429688.
# 2020-05-12 19:18:55 : After 450 training step(s), loss,accuracy on training batch is 1.77603 , 0.453125.
# 2020-05-12 19:18:56 : After 455 training step(s), loss,accuracy on training batch is 1.75862 , 0.421875.
# 2020-05-12 19:18:56 : After 460 training step(s), loss,accuracy on training batch is 1.85919 , 0.46875.
# 2020-05-12 19:18:57 : After 465 training step(s), loss,accuracy on training batch is 1.67959 , 0.46875.
# 2020-05-12 19:18:58 : After 470 training step(s), loss,accuracy on training batch is 1.7229 , 0.515625.
# 2020-05-12 19:18:59 : After 475 training step(s), loss,accuracy on training batch is 1.70518 , 0.484375.
# 2020-05-12 19:19:00 : After 480 training step(s), loss,accuracy on training batch is 1.87051 , 0.429688.
# 2020-05-12 19:19:00 : After 485 training step(s), loss,accuracy on training batch is 1.89403 , 0.429688.
# 2020-05-12 19:19:01 : After 490 training step(s), loss,accuracy on training batch is 1.72372 , 0.445312.
# 2020-05-12 19:19:02 : After 495 training step(s), loss,accuracy on training batch is 1.72874 , 0.4375.
# 2020-05-12 19:19:03 : After 500 training step(s), loss,accuracy on training batch is 1.61618 , 0.5.

# %%
api.prepare_sess()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0345d5de0a2d> in <module>
# ----> 1 api.prepare_sess()
#
# ~/MyFiles/repo/fer2013/fer_api.py in prepare_sess(self, tModel)
#      61     def prepare_sess(self,tModel=''):
#      62         if self.sess:
# ---> 63             sess.close()
#      64         if tModel == '':
#      65             ckpt = tf.train.get_checkpoint_state(config.MODEL_SAVE_PATH)
#
# NameError: name 'sess' is not defined

# %%
api.sess_perform('/home/ubuntu/MyFiles/data/fer2013/valid/46_3.png')
